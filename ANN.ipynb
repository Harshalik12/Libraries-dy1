# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshalik12/Libraries-dy1/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcom to the ANN!!")
# Out:
# Welcom to the ANN!!
